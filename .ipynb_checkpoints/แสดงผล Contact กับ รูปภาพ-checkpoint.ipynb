# %% [markdown]
# ## Read file

# %%
import pandas as pd
df_62 = pd.read_csv("Data/CS-62-Data-Set.csv")
df_62.head()
# Out:
#    NO           ID                        Name  Status  Round
# 0   1  623020032-3            นายกมล ศิลารักษ์      10  Q62A1
# 1   2  623020033-1  นายกิตติศักดิ์ เหง้าศรีไพร      10  Q62A1
# 2   3  623020034-9     นางสาวจุฑาทิพย์ บุญรมย์      10  Q62A1
# 3   4  623020035-7        นางสาวจุฑามาศ คงระวี      50  Q62A1
# 4   5  623020036-5          นายณัฐวัฒน์ แซ่ตัง      10  Q62A1

# %% [markdown]
# ## Show Data and Image

# %%
import numpy as np
index = 89
label = np.arange(109)

# %%
df_62.iloc[index]
# Out:
# NO                          90
# ID                 623021016-6
# Name      นายชาญยุทธ ไวสูงเนิน
# Status                      10
# Round                    Q62A4
# Name: 89, dtype: object

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread(f'Data/{label[index]}.png')
imgplot = plt.imshow(img)
plt.show();
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
## Show Data and Image

index = 89

print(df_62.iloc[index])

# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img=mpimg.imread(f'Data/{label[index]}.png')
imgplot = plt.imshow(img)
plt.show();
# Out:
# NO                          90
# ID                 623021016-6
# Name      นายชาญยุทธ ไวสูงเนิน
# Status                      10
# Round                    Q62A4
# Name: 89, dtype: object
# Populating the interactive namespace from numpy and matplotlib
