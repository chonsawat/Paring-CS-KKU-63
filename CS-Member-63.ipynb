# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("SC-63-Member.csv", encoding="utf-8")
cs_df = df[df.Major == "วิทยาการคอมพิวเตอร์"]

# %%
cs_df
# Out:
#       No             ID                          Name               Branch  \
# 721    1    633020032-4       นายกล้ายุทธ   พิชัยเชิด  วิทยาการคอมพิวเตอร์
# 722    2    633020033-2         นายจิรภัทร   ชื่นสกุล  วิทยาการคอมพิวเตอร์
# 723    3    633020034-0           นายชาญยุทธ   ดงทะนา  วิทยาการคอมพิวเตอร์
# 724    4    633020035-8            นายชานน   ภาคีนุยะ  วิทยาการคอมพิวเตอร์
# 725    5    633020036-6          นายณัฐนันท์   วรรณภา  วิทยาการคอมพิวเตอร์
# ..   ...            ...                           ...                  ...
# 825  105    633021006-0         นางสาวสุภาวดี   มาวัน  วิทยาการคอมพิวเตอร์
# 826  106    633021007-8            นายอนุชา   เงินขาว  วิทยาการคอมพิวเตอร์
# 827  107    633021008-6          นายอภิวัฒน์   แก้วกำ  วิทยาการคอมพิวเตอร์
# 828  108    633021009-4   นายอัครเดช   วิทยาวุฒิรัตน์  วิทยาการคอมพิวเตอร์
# 829  109    633021010-9           นายอัษฎาวุธ   หอมดี  วิทยาการคอมพิวเตอร์
#
#                    Major
# 721  วิทยาการคอมพิวเตอร์
# ...

# %%
len(cs_df)
# Out:
# 109

# %%
cs_df.to_csv("CS-63-Member.csv", index=False)

# %%
cs_df = pd.read_csv("CS-63-Member.csv")
cs_df
# Out:
#       No             ID                          Name               Branch  \
# 0      1    633020032-4       นายกล้ายุทธ   พิชัยเชิด  วิทยาการคอมพิวเตอร์
# 1      2    633020033-2         นายจิรภัทร   ชื่นสกุล  วิทยาการคอมพิวเตอร์
# 2      3    633020034-0           นายชาญยุทธ   ดงทะนา  วิทยาการคอมพิวเตอร์
# 3      4    633020035-8            นายชานน   ภาคีนุยะ  วิทยาการคอมพิวเตอร์
# 4      5    633020036-6          นายณัฐนันท์   วรรณภา  วิทยาการคอมพิวเตอร์
# ..   ...            ...                           ...                  ...
# 104  105    633021006-0         นางสาวสุภาวดี   มาวัน  วิทยาการคอมพิวเตอร์
# 105  106    633021007-8            นายอนุชา   เงินขาว  วิทยาการคอมพิวเตอร์
# 106  107    633021008-6          นายอภิวัฒน์   แก้วกำ  วิทยาการคอมพิวเตอร์
# 107  108    633021009-4   นายอัครเดช   วิทยาวุฒิรัตน์  วิทยาการคอมพิวเตอร์
# 108  109    633021010-9           นายอัษฎาวุธ   หอมดี  วิทยาการคอมพิวเตอร์
#
#                    Major
# 0    วิทยาการคอมพิวเตอร์
# ...
